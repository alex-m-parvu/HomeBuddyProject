# %%
import pandas as pd
from DS_Helpers.filters import column_filter
from DS_Helpers.data import other_generator_columns, find_embed_object_cols, get_days_to_nearest_holiday
from DS_Helpers.metrics import classification_result
from DS_Helpers.models import simple_preprocessing, log_scaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from copy import deepcopy
import matplotlib.pyplot as plt

# %%
leads = column_filter(pd.read_csv('data/leads_dataset.csv'), tolerance=0.4)
leads.LEAD_CREATED_AT_UTC = pd.to_datetime(leads.LEAD_CREATED_AT_UTC)


infutor_enrichment_dataset = column_filter(pd.read_csv('data/infutor_enrichment_dataset.csv', index_col=0), tolerance=0.4)
zip_code_dataset = column_filter(pd.read_csv('data/zip_code_dataset.csv'), tolerance=0.3)

# %%
leads.head()
# Out:
#                         HASHED_PHONE_NUMBER IS_APPOINTMENT_SET  \
# 0  16bc446a779996bf3007065819f1dd4692a17d14               True
# 1  6d30f0d0f87d39f8c178e3750072eef79bb9d7a0              False
# 2  9de207ef32d3696829ae369c2a9a4500cd36ec43               True
# 3  31bb43ece722562df3a163ba94be4eb2ccd1bf71              False
# 4  674de0e7b4da1c9945422b248f94cbf2499d59e2              False
#
#         LEAD_CREATED_AT_UTC  ZIP_CODE          CITY STATE     COUNTY  \
# 0 2023-07-18 15:11:55+00:00   61080.0  South Beloit    IL  Winnebago
# 1 2022-09-19 18:37:21+00:00   33914.0    Cape Coral    FL        Lee
# 2 2022-11-09 21:38:10+00:00   42055.0       Kuttawa    KY       Lyon
# 3 2022-11-13 15:41:31+00:00   43701.0    Zanesville    OH  Muskingum
# 4 2022-10-07 17:56:51+00:00   22206.0     Arlington    VA  Arlington
#
#   EMAIL_DOMAIN OPERATINGSYSTEMCLASS OPERATINGSYSTEMNAME       AGENTNAME  \
# 0    gmail.com               Mobile             Android  Chrome Webview
# 1    gmail.com               Mobile                 iOS       UIWebView
# 2    gmail.com               Mobile             Android  Chrome Webview
# 3    gmail.com               Mobile                 iOS       UIWebView
# 4    gmail.com               Mobile                 iOS       UIWebView
#
#   AGENTVERSIONMAJOR DEVICEBRAND        DEVICENAME LAYOUTENGINENAME  \
# 0               114     Samsung  Samsung SM-A546V            Blink
# 1               605       Apple      Apple iPhone      AppleWebKit
# 2               105     Samsung  Samsung SM-G991U            Blink
# 3               605       Apple      Apple iPhone      AppleWebKit
# 4               605       Apple      Apple iPhone      AppleWebKit
#
#   NETWORKTYPE OPERATINGSYSTEMVERSIONMAJOR            WEBVIEWAPPNAME
# 0     Unknown                          13                 Newsbreak
# 1     Unknown                          15      Facebook App for iOS
# 2     Unknown                          12  Facebook App for Android
# 3     Unknown                          15      Facebook App for iOS
# 4     Unknown                          16      Facebook App for iOS

# %%
(leads.IS_APPOINTMENT_SET.value_counts()/leads.shape[0]).plot.bar();

# %%
infutor_enrichment_dataset.dtypes
# Out:
# HASHED_PHONE_NUMBER                                      object
# MATCHLEVEL                                                int64
# ATTRIBUTES_COREDEMOGRAPHICS_DOB                         float64
# ATTRIBUTES_COREDEMOGRAPHICS_GENDER                       object
# ATTRIBUTES_COREDEMOGRAPHICS_MARRIEDCD                    object
# ATTRIBUTES_COREDEMOGRAPHICS_WEALTHSCR                    object
# ATTRIBUTES_COREDEMOGRAPHICS_HOMEOWNERCD                  object
# ATTRIBUTES_COREDEMOGRAPHICS_EHI                          object
# ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CREDITCARD           object
# ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_YRBLD               float64
# ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_LOR                 float64
# ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_HHNBR               float64
# ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CENS_POP_DENSITY    float64
# dtype: object

# %%
infutor_enrichment_dataset.head()
# Out:
#                         HASHED_PHONE_NUMBER  MATCHLEVEL  \
# 0  9a99e383ee68a51c2740de9883f5b1bee5d2a4da           1
# 1  0020b0a911711b66c100d7e8e25e226783bb0072           5
# 2  d436912ed29db2950ca13b64cc56fefc0f581f7a           1
# 3  c2bd44a987bc7b9663352235ea2b7bb04b696697           5
# 4  c363fb2c7bbdd728928716b4d5b4a80a13cbd2f2           1
#
#    ATTRIBUTES_COREDEMOGRAPHICS_DOB ATTRIBUTES_COREDEMOGRAPHICS_GENDER  \
# 0                         197010.0                                  M
# 1                         194702.0                                  M
# 2                         196410.0                                  F
# 3                              NaN                                  F
# 4                         197009.0                                  M
#
#   ATTRIBUTES_COREDEMOGRAPHICS_MARRIEDCD ATTRIBUTES_COREDEMOGRAPHICS_WEALTHSCR  \
# 0                                     M                                     A
# 1                                   NaN                                   NaN
# 2                                     M                                     E
# 3                                   NaN                                   NaN
# 4                                     S                                     D
#
#   ATTRIBUTES_COREDEMOGRAPHICS_HOMEOWNERCD ATTRIBUTES_COREDEMOGRAPHICS_EHI  \
# 0                                       H                               J
# 1                                     NaN                             NaN
# 2                                       H                               I
# 3                                     NaN                             NaN
# 4                                       U                               E
#
#   ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CREDITCARD  \
# 0                                              Y
# 1                                            NaN
# 2                                              Y
# 3                                            NaN
# 4                                              Y
#
#    ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_YRBLD  \
# 0                                     1959.0
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_LOR  \
# 0                                      6.0
# 1                                      NaN
# 2                                      9.0
# 3                                      NaN
# 4                                     15.0
#
#    ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_HHNBR  \
# 0                                        2.0
# 1                                        NaN
# 2                                        2.0
# 3                                        NaN
# 4                                        2.0
#
#    ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CENS_POP_DENSITY
# 0                                             3801.0
# 1                                                NaN
# 2                                              294.0
# 3                                                NaN
# 4                                                NaN

# %%
data = pd.merge(left=leads, right=infutor_enrichment_dataset, on='HASHED_PHONE_NUMBER', how='left')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318565 entries, 0 to 318564
# Data columns (total 30 columns):
#  #   Column                                                Non-Null Count   Dtype
# ---  ------                                                --------------   -----
#  0   HASHED_PHONE_NUMBER                                   318565 non-null  object
#  1   IS_APPOINTMENT_SET                                    315348 non-null  object
#  2   LEAD_CREATED_AT_UTC                                   315348 non-null  datetime64[ns, UTC]
#  3   ZIP_CODE                                              315348 non-null  float64
#  4   CITY                                                  315309 non-null  object
#  5   STATE                                                 315309 non-null  object
#  6   COUNTY                                                315309 non-null  object
#  7   EMAIL_DOMAIN                                          315348 non-null  object
#  8   OPERATINGSYSTEMCLASS                                  315331 non-null  object
#  9   OPERATINGSYSTEMNAME                                   315331 non-null  object
#  10  AGENTNAME                                             315331 non-null  object
#  11  AGENTVERSIONMAJOR                                     315331 non-null  object
#  12  DEVICEBRAND                                           315331 non-null  object
#  13  DEVICENAME                                            315331 non-null  object
#  14  LAYOUTENGINENAME                                      315331 non-null  object
#  15  NETWORKTYPE                                           315331 non-null  object
#  16  OPERATINGSYSTEMVERSIONMAJOR                           315331 non-null  object
#  17  WEBVIEWAPPNAME                                        315331 non-null  object
#  18  MATCHLEVEL                                            204688 non-null  float64
#  19  ATTRIBUTES_COREDEMOGRAPHICS_DOB                       170406 non-null  float64
#  20  ATTRIBUTES_COREDEMOGRAPHICS_GENDER                    200604 non-null  object
#  21  ATTRIBUTES_COREDEMOGRAPHICS_MARRIEDCD                 143097 non-null  object
#  22  ATTRIBUTES_COREDEMOGRAPHICS_WEALTHSCR                 158445 non-null  object
#  23  ATTRIBUTES_COREDEMOGRAPHICS_HOMEOWNERCD               156864 non-null  object
#  24  ATTRIBUTES_COREDEMOGRAPHICS_EHI                       157601 non-null  object
#  25  ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CREDITCARD        131330 non-null  object
#  26  ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_YRBLD             132560 non-null  float64
#  27  ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_LOR               158790 non-null  float64
#  28  ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_HHNBR             158795 non-null  float64
#  29  ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CENS_POP_DENSITY  157678 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(7), object(22)
# memory usage: 72.9+ MB

# %%
zip_code_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19692 entries, 0 to 19691
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ZIP_CODE            19691 non-null  float64
#  1   Alchemist           19691 non-null  float64
#  2   Ancient Apparition  19691 non-null  float64
#  3   Anti-Mage           19691 non-null  float64
#  4   Axe                 19691 non-null  float64
#  5   Batrider            19691 non-null  float64
#  6   Beastmaster         19691 non-null  float64
#  7   Chaos Knight        19691 non-null  float64
#  8   Chen                19691 non-null  float64
#  9   Clinkz              19691 non-null  float64
#  10  Clockwerk           19691 non-null  float64
#  11  Crystal Maiden      19691 non-null  float64
#  12  Dark Seer           19691 non-null  float64
#  13  Dazzle              19691 non-null  float64
#  14  Death Prophet       19691 non-null  float64
#  15  Doom                19691 non-null  float64
#  16  Dragon Knight       19691 non-null  float64
#  17  Drow Ranger         19691 non-null  float64
#  18  Earth Spirit        19691 non-null  float64
#  19  Earthshaker         19691 non-null  float64
#  20  Elder Titan         19691 non-null  float64
#  21  Ember Spirit        19691 non-null  float64
#  22  Enchantress         19691 non-null  float64
#  23  Enigma              19691 non-null  float64
#  24  Faceless Void       19691 non-null  float64
#  25  Pudge               19691 non-null  float64
# dtypes: float64(26)
# memory usage: 3.9 MB

# %%
zip_code_dataset.head()
# Out:
#    ZIP_CODE  Alchemist  Ancient Apparition  Anti-Mage   Axe  Batrider  \
# 0   47327.0     2065.0              1403.0       40.5  42.1      18.0
# 1   71268.0      347.0               257.0       40.6  40.6      17.0
# 2   27828.0     3581.0              2519.0       39.2  38.8      17.0
# 3   30143.0     7863.0              5681.0       46.4  49.5      27.0
# 4   25564.0       90.0                77.0       37.4  36.8      20.0
#
#    Beastmaster  Chaos Knight  Chen  Clinkz  ...  Dragon Knight  Drow Ranger  \
# 0          7.0          93.0  62.0    26.0  ...         1081.0        840.0
# 1          7.0          93.0  62.0    34.0  ...         1205.0        910.0
# 2         10.0          90.0  59.0    29.0  ...         1533.0       1288.0
# 3          2.0          98.0  75.0    29.0  ...         2654.0       2445.0
# 4          2.0          98.0  77.0    16.0  ...         1545.0       1125.0
#
#    Earth Spirit  Earthshaker  Elder Titan  Ember Spirit  Enchantress  Enigma  \
# 0          16.0         14.0         25.0          12.0         76.0    83.0
# 1          21.0         21.0         31.0          16.0         90.0    74.0
# 2          24.0         20.0         34.0          21.0         68.0    73.0
# 3           9.0          9.0         14.0           9.0         79.0    84.0
# 4           0.0         22.0          0.0           0.0         80.0    68.0
#
#    Faceless Void   Pudge
# 0            3.0  1952.0
# 1            0.0  1991.0
# 2            3.0  1990.0
# 3            1.0  1994.0
# 4            0.0  1987.0
#
# [5 rows x 26 columns]

# %%
data = pd.merge(left=data, right=zip_code_dataset, on='ZIP_CODE', how='left')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334904 entries, 0 to 334903
# Data columns (total 55 columns):
#  #   Column                                                Non-Null Count   Dtype
# ---  ------                                                --------------   -----
#  0   HASHED_PHONE_NUMBER                                   334904 non-null  object
#  1   IS_APPOINTMENT_SET                                    331687 non-null  object
#  2   LEAD_CREATED_AT_UTC                                   331687 non-null  datetime64[ns, UTC]
#  3   ZIP_CODE                                              331687 non-null  float64
#  4   CITY                                                  331648 non-null  object
#  5   STATE                                                 331648 non-null  object
#  6   COUNTY                                                331648 non-null  object
#  7   EMAIL_DOMAIN                                          331687 non-null  object
#  8   OPERATINGSYSTEMCLASS                                  331668 non-null  object
#  9   OPERATINGSYSTEMNAME                                   331668 non-null  object
#  10  AGENTNAME                                             331668 non-null  object
#  11  AGENTVERSIONMAJOR                                     331668 non-null  object
#  12  DEVICEBRAND                                           331668 non-null  object
#  13  DEVICENAME                                            331668 non-null  object
#  14  LAYOUTENGINENAME                                      331668 non-null  object
#  15  NETWORKTYPE                                           331668 non-null  object
#  16  OPERATINGSYSTEMVERSIONMAJOR                           331668 non-null  object
#  17  WEBVIEWAPPNAME                                        331668 non-null  object
#  18  MATCHLEVEL                                            215233 non-null  float64
#  19  ATTRIBUTES_COREDEMOGRAPHICS_DOB                       179191 non-null  float64
#  20  ATTRIBUTES_COREDEMOGRAPHICS_GENDER                    210941 non-null  object
#  21  ATTRIBUTES_COREDEMOGRAPHICS_MARRIEDCD                 150415 non-null  object
#  22  ATTRIBUTES_COREDEMOGRAPHICS_WEALTHSCR                 166618 non-null  object
#  23  ATTRIBUTES_COREDEMOGRAPHICS_HOMEOWNERCD               164978 non-null  object
#  24  ATTRIBUTES_COREDEMOGRAPHICS_EHI                       165734 non-null  object
#  25  ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CREDITCARD        138169 non-null  object
#  26  ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_YRBLD             139324 non-null  float64
#  27  ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_LOR               166995 non-null  float64
#  28  ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_HHNBR             167000 non-null  float64
#  29  ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CENS_POP_DENSITY  165817 non-null  float64
#  30  Alchemist                                             331648 non-null  float64
#  31  Ancient Apparition                                    331648 non-null  float64
#  32  Anti-Mage                                             331648 non-null  float64
#  33  Axe                                                   331648 non-null  float64
#  34  Batrider                                              331648 non-null  float64
#  35  Beastmaster                                           331648 non-null  float64
#  36  Chaos Knight                                          331648 non-null  float64
#  37  Chen                                                  331648 non-null  float64
#  38  Clinkz                                                331648 non-null  float64
#  39  Clockwerk                                             331648 non-null  float64
#  40  Crystal Maiden                                        331648 non-null  float64
#  41  Dark Seer                                             331648 non-null  float64
#  42  Dazzle                                                331648 non-null  float64
#  43  Death Prophet                                         331648 non-null  float64
#  44  Doom                                                  331648 non-null  float64
#  45  Dragon Knight                                         331648 non-null  float64
#  46  Drow Ranger                                           331648 non-null  float64
#  47  Earth Spirit                                          331648 non-null  float64
#  48  Earthshaker                                           331648 non-null  float64
#  49  Elder Titan                                           331648 non-null  float64
#  50  Ember Spirit                                          331648 non-null  float64
#  51  Enchantress                                           331648 non-null  float64
#  52  Enigma                                                331648 non-null  float64
#  53  Faceless Void                                         331648 non-null  float64
#  54  Pudge                                                 331648 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(32), object(22)
# memory usage: 140.5+ MB

# %%
data.head()
# Out:
#                         HASHED_PHONE_NUMBER IS_APPOINTMENT_SET  \
# 0  16bc446a779996bf3007065819f1dd4692a17d14               True
# 1  6d30f0d0f87d39f8c178e3750072eef79bb9d7a0              False
# 2  9de207ef32d3696829ae369c2a9a4500cd36ec43               True
# 3  31bb43ece722562df3a163ba94be4eb2ccd1bf71              False
# 4  674de0e7b4da1c9945422b248f94cbf2499d59e2              False
#
#         LEAD_CREATED_AT_UTC  ZIP_CODE          CITY STATE     COUNTY  \
# 0 2023-07-18 15:11:55+00:00   61080.0  South Beloit    IL  Winnebago
# 1 2022-09-19 18:37:21+00:00   33914.0    Cape Coral    FL        Lee
# 2 2022-11-09 21:38:10+00:00   42055.0       Kuttawa    KY       Lyon
# 3 2022-11-13 15:41:31+00:00   43701.0    Zanesville    OH  Muskingum
# 4 2022-10-07 17:56:51+00:00   22206.0     Arlington    VA  Arlington
#
#   EMAIL_DOMAIN OPERATINGSYSTEMCLASS OPERATINGSYSTEMNAME  ... Dragon Knight  \
# 0    gmail.com               Mobile             Android  ...        1385.0
# 1    gmail.com               Mobile                 iOS  ...        3253.0
# 2    gmail.com               Mobile             Android  ...        1400.0
# 3    gmail.com               Mobile                 iOS  ...        1464.0
# 4    gmail.com               Mobile                 iOS  ...        4399.0
#
#   Drow Ranger Earth Spirit Earthshaker Elder Titan Ember Spirit Enchantress  \
# 0      1244.0          7.0        10.0        13.0          4.0        71.0
# 1      2845.0          9.0         8.0        15.0          6.0        78.0
# 2      1098.0         16.0         6.0        31.0         12.0        91.0
# 3      1140.0         20.0        18.0        33.0         23.0        63.0
# 4      4375.0          4.0         3.0         4.0          2.0        55.0
#
#   Enigma  Faceless Void   Pudge
# 0   87.0            3.0  1984.0
# 1   83.0            3.0  1998.0
# 2   60.0            0.0  1981.0
# 3   72.0            4.0  1964.0
# 4   45.0            1.0  1948.0
#
# [5 rows x 55 columns]

# %%
get_days_to_nearest_holiday(date_input=data.LEAD_CREATED_AT_UTC[0], country_code='US')
# Out:
# 14

# %%
data['days_to_holiday'] = data['LEAD_CREATED_AT_UTC'].apply(lambda x: get_days_to_nearest_holiday(x, country_code='US') if pd.notnull(x) else None)
data.head()
# Out:
#                         HASHED_PHONE_NUMBER IS_APPOINTMENT_SET  \
# 0  16bc446a779996bf3007065819f1dd4692a17d14               True
# 1  6d30f0d0f87d39f8c178e3750072eef79bb9d7a0              False
# 2  9de207ef32d3696829ae369c2a9a4500cd36ec43               True
# 3  31bb43ece722562df3a163ba94be4eb2ccd1bf71              False
# 4  674de0e7b4da1c9945422b248f94cbf2499d59e2              False
#
#         LEAD_CREATED_AT_UTC  ZIP_CODE          CITY STATE     COUNTY  \
# 0 2023-07-18 15:11:55+00:00   61080.0  South Beloit    IL  Winnebago
# 1 2022-09-19 18:37:21+00:00   33914.0    Cape Coral    FL        Lee
# 2 2022-11-09 21:38:10+00:00   42055.0       Kuttawa    KY       Lyon
# 3 2022-11-13 15:41:31+00:00   43701.0    Zanesville    OH  Muskingum
# 4 2022-10-07 17:56:51+00:00   22206.0     Arlington    VA  Arlington
#
#   EMAIL_DOMAIN OPERATINGSYSTEMCLASS OPERATINGSYSTEMNAME  ... Drow Ranger  \
# 0    gmail.com               Mobile             Android  ...      1244.0
# 1    gmail.com               Mobile                 iOS  ...      2845.0
# 2    gmail.com               Mobile             Android  ...      1098.0
# 3    gmail.com               Mobile                 iOS  ...      1140.0
# 4    gmail.com               Mobile                 iOS  ...      4375.0
#
#   Earth Spirit Earthshaker Elder Titan Ember Spirit Enchantress Enigma  \
# 0          7.0        10.0        13.0          4.0        71.0   87.0
# 1          9.0         8.0        15.0          6.0        78.0   83.0
# 2         16.0         6.0        31.0         12.0        91.0   60.0
# 3         20.0        18.0        33.0         23.0        63.0   72.0
# 4          4.0         3.0         4.0          2.0        55.0   45.0
#
#   Faceless Void   Pudge  days_to_holiday
# 0           3.0  1984.0             14.0
# 1           3.0  1998.0             14.0
# 2           0.0  1981.0              2.0
# 3           4.0  1964.0              2.0
# 4           1.0  1948.0              3.0
#
# [5 rows x 56 columns]

# %%
data = data[ ~data.IS_APPOINTMENT_SET.isna() ]
data = data.drop( labels='HASHED_PHONE_NUMBER ZIP_CODE'.split(), axis=1 )
data.shape
# Out:
# (331687, 54)

# %%
y = data.IS_APPOINTMENT_SET
X = data.drop(labels='IS_APPOINTMENT_SET', axis=1)
X.head()
# Out:
#         LEAD_CREATED_AT_UTC          CITY STATE     COUNTY EMAIL_DOMAIN  \
# 0 2023-07-18 15:11:55+00:00  South Beloit    IL  Winnebago    gmail.com
# 1 2022-09-19 18:37:21+00:00    Cape Coral    FL        Lee    gmail.com
# 2 2022-11-09 21:38:10+00:00       Kuttawa    KY       Lyon    gmail.com
# 3 2022-11-13 15:41:31+00:00    Zanesville    OH  Muskingum    gmail.com
# 4 2022-10-07 17:56:51+00:00     Arlington    VA  Arlington    gmail.com
#
#   OPERATINGSYSTEMCLASS OPERATINGSYSTEMNAME       AGENTNAME AGENTVERSIONMAJOR  \
# 0               Mobile             Android  Chrome Webview               114
# 1               Mobile                 iOS       UIWebView               605
# 2               Mobile             Android  Chrome Webview               105
# 3               Mobile                 iOS       UIWebView               605
# 4               Mobile                 iOS       UIWebView               605
#
#   DEVICEBRAND  ... Drow Ranger Earth Spirit Earthshaker Elder Titan  \
# 0     Samsung  ...      1244.0          7.0        10.0        13.0
# 1       Apple  ...      2845.0          9.0         8.0        15.0
# 2     Samsung  ...      1098.0         16.0         6.0        31.0
# 3       Apple  ...      1140.0         20.0        18.0        33.0
# 4       Apple  ...      4375.0          4.0         3.0         4.0
#
#   Ember Spirit  Enchantress  Enigma Faceless Void   Pudge days_to_holiday
# 0          4.0         71.0    87.0           3.0  1984.0            14.0
# 1          6.0         78.0    83.0           3.0  1998.0            14.0
# 2         12.0         91.0    60.0           0.0  1981.0             2.0
# 3         23.0         63.0    72.0           4.0  1964.0             2.0
# 4          2.0         55.0    45.0           1.0  1948.0             3.0
#
# [5 rows x 53 columns]

# %%
X['Year'] = X.LEAD_CREATED_AT_UTC.dt.year
X['Month'] = X.LEAD_CREATED_AT_UTC.dt.month.astype('str')
X['Weekday'] = X.LEAD_CREATED_AT_UTC.dt.weekday.astype('str')
X['Day'] = X.LEAD_CREATED_AT_UTC.dt.day.astype('str')
X['Hour'] = X.LEAD_CREATED_AT_UTC.dt.hour.astype('str')
X = X.drop(labels='LEAD_CREATED_AT_UTC',axis=1)
X.head()
# Out:
#            CITY STATE     COUNTY EMAIL_DOMAIN OPERATINGSYSTEMCLASS  \
# 0  South Beloit    IL  Winnebago    gmail.com               Mobile
# 1    Cape Coral    FL        Lee    gmail.com               Mobile
# 2       Kuttawa    KY       Lyon    gmail.com               Mobile
# 3    Zanesville    OH  Muskingum    gmail.com               Mobile
# 4     Arlington    VA  Arlington    gmail.com               Mobile
#
#   OPERATINGSYSTEMNAME       AGENTNAME AGENTVERSIONMAJOR DEVICEBRAND  \
# 0             Android  Chrome Webview               114     Samsung
# 1                 iOS       UIWebView               605       Apple
# 2             Android  Chrome Webview               105     Samsung
# 3                 iOS       UIWebView               605       Apple
# 4                 iOS       UIWebView               605       Apple
#
#          DEVICENAME  ... Enchantress Enigma Faceless Void   Pudge  \
# 0  Samsung SM-A546V  ...        71.0   87.0           3.0  1984.0
# 1      Apple iPhone  ...        78.0   83.0           3.0  1998.0
# 2  Samsung SM-G991U  ...        91.0   60.0           0.0  1981.0
# 3      Apple iPhone  ...        63.0   72.0           4.0  1964.0
# 4      Apple iPhone  ...        55.0   45.0           1.0  1948.0
#
#    days_to_holiday  Year Month Weekday Day Hour
# 0             14.0  2023     7       1  18   15
# 1             14.0  2022     9       0  19   18
# 2              2.0  2022    11       2   9   21
# 3              2.0  2022    11       6  13   15
# 4              3.0  2022    10       4   7   17
#
# [5 rows x 57 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
X_train = other_generator_columns(df=X_train, other_threshold=50)
X_train.head()
# Out:
#                  CITY STATE      COUNTY EMAIL_DOMAIN OPERATINGSYSTEMCLASS  \
# 167862  Grand Prairie    TX      Dallas    yahoo.com               Mobile
# 24856         Newport    OH  Washington      aol.com              Desktop
# 61660          Venice    FL    Sarasota    gmail.com               Mobile
# 103831      Las Vegas    NV       Clark      cox.net               Mobile
# 155381           Katy    TX      Harris    ymail.com               Mobile
#
#        OPERATINGSYSTEMNAME  AGENTNAME AGENTVERSIONMAJOR DEVICEBRAND  \
# 167862                 iOS  UIWebView               605       Apple
# 24856           Windows NT     Chrome               100     Unknown
# 61660              Android     Chrome               116     Unknown
# 103831                 iOS  UIWebView               605       Apple
# 155381                 iOS  UIWebView               605       Apple
#
#             DEVICENAME  ... Enchantress Enigma Faceless Void   Pudge  \
# 167862    Apple iPhone  ...        73.0   82.0           1.0  1993.0
# 24856          Desktop  ...        67.0   87.0           0.0  1974.0
# 61660   Android Mobile  ...        86.0   86.0           1.0  1989.0
# 103831      Apple iPad  ...        48.0   64.0           1.0  1994.0
# 155381    Apple iPhone  ...        82.0   90.0           0.0  1995.0
#
#         days_to_holiday  Year Month Weekday Day Hour
# 167862              4.0  2022    12       2  21   18
# 24856              36.0  2022     4       6  24   13
# 61660               5.0  2023     9       5   9   16
# 103831             16.0  2023    10       2  25   23
# 155381              3.0  2022     9       3   8   19
#
# [5 rows x 57 columns]

# %%
X_test = other_generator_columns(df=X_test, other_threshold=50)
X_test.head()
# Out:
#               CITY STATE      COUNTY EMAIL_DOMAIN OPERATINGSYSTEMCLASS  \
# 172371       other    NC     Forsyth    gmail.com               Mobile
# 323635  Cincinnati    OH    Hamilton    gmail.com               Mobile
# 291688       other    OH     Licking        other               Mobile
# 310280       other    TX      Harris    gmail.com              Desktop
# 85031        other    RI  Providence    gmail.com               Mobile
#
#        OPERATINGSYSTEMNAME       AGENTNAME AGENTVERSIONMAJOR DEVICEBRAND  \
# 172371             Android  Chrome Webview               102      Google
# 323635                 iOS       UIWebView               605       Apple
# 291688                 iOS          Safari                14       Apple
# 310280          Windows NT          Chrome               104     Unknown
# 85031              Android  Chrome Webview                87     Unknown
#
#           DEVICENAME  ... Enchantress Enigma Faceless Void   Pudge  \
# 172371         other  ...        83.0   82.0           0.0  1992.0
# 323635  Apple iPhone  ...        66.0   70.0           1.0  1977.0
# 291688  Apple iPhone  ...        61.0   62.0          11.0  1952.0
# 310280       Desktop  ...        77.0   80.0           0.0  1977.0
# 85031         DE2118  ...        36.0   24.0          18.0  1941.0
#
#         days_to_holiday  Year Month Weekday Day Hour
# 172371              7.0  2022     6       6  12   14
# 323635             11.0  2022     7       4  15   17
# 291688             27.0  2022     8       1   9   15
# 310280              4.0  2022     9       3   1   17
# 85031              18.0  2023     5       3  11   22
#
# [5 rows x 57 columns]

# %%
obj_embed = find_embed_object_cols(df=X_train, embedding_dims=16)

X_train_embed = obj_embed['df']
X_train_embed.head()
# Out:
# CITY
# STATE
# COUNTY
# EMAIL_DOMAIN
# OPERATINGSYSTEMCLASS
# OPERATINGSYSTEMNAME
# AGENTNAME
# AGENTVERSIONMAJOR
# DEVICEBRAND
# DEVICENAME
# LAYOUTENGINENAME
# NETWORKTYPE
# OPERATINGSYSTEMVERSIONMAJOR
# WEBVIEWAPPNAME
# ATTRIBUTES_COREDEMOGRAPHICS_GENDER
# ATTRIBUTES_COREDEMOGRAPHICS_MARRIEDCD
# ATTRIBUTES_COREDEMOGRAPHICS_WEALTHSCR
# ATTRIBUTES_COREDEMOGRAPHICS_HOMEOWNERCD
# ATTRIBUTES_COREDEMOGRAPHICS_EHI
# ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CREDITCARD
# Month
# Weekday
# Day
# Hour
#         MATCHLEVEL  ATTRIBUTES_COREDEMOGRAPHICS_DOB  \
# 167862         5.0                         197108.0
# 24856          NaN                              NaN
# 61660          1.0                         192107.0
# 103831         1.0                         196612.0
# 155381         NaN                              NaN
#
#         ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_YRBLD  \
# 167862                                        NaN
# 24856                                         NaN
# 61660                                      1997.0
# 103831                                        NaN
# 155381                                        NaN
#
#         ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_LOR  \
# 167862                                      NaN
# 24856                                       NaN
# 61660                                      15.0
# 103831                                     15.0
# 155381                                      NaN
#
#         ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_HHNBR  \
# 167862                                        NaN
# 24856                                         NaN
# 61660                                         1.0
# 103831                                        2.0
# 155381                                        NaN
#
#         ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CENS_POP_DENSITY  Alchemist  \
# 167862                                                NaN       28723.0
# 24856                                                 NaN         486.0
# 61660                                               475.0       16531.0
# 103831                                             6705.0       18704.0
# 155381                                                NaN        7904.0
#
#         Ancient Apparition  Anti-Mage   Axe  ...  Hour_V_6  Hour_V_7  \
# 167862             22943.0       35.5  35.2  ...       166       167
# 24856                320.0       45.1  47.7  ...        86        87
# 61660              11084.0       55.0  62.0  ...       134       135
# 103831             11969.0       39.8  38.9  ...       262       263
# 155381              6579.0       36.4  36.5  ...       182       183
#
#         Hour_V_8  Hour_V_9  Hour_V_10  Hour_V_11  Hour_V_12  Hour_V_13  \
# 167862       168       169        170        171        172        173
# 24856         88        89         90         91         92         93
# 61660        136       137        138        139        140        141
# 103831       264       265        266        267        268        269
# 155381       184       185        186        187        188        189
#
#         Hour_V_14  Hour_V_15
# 167862        174        175
# 24856          94         95
# 61660         142        143
# 103831        270        271
# 155381        190        191
#
# [5 rows x 417 columns]

# %%
X_test_embeding = X_test.copy()

embedings = obj_embed['embedings']

key = list(embedings.keys())[0]

for key in embedings.keys():

    embeding_df = embedings[key].transform( X_test_embeding[key] )
    embeding_df.index = X_test_embeding.index
    X_test_embeding = pd.concat( objs=[X_test_embeding, embeding_df], axis=1 )
    X_test_embeding = X_test_embeding.drop(labels=key, axis=1)


X_test_embeding.head()
# Out:
#         MATCHLEVEL  ATTRIBUTES_COREDEMOGRAPHICS_DOB  \
# 172371         NaN                              NaN
# 323635         1.0                         195607.0
# 291688         NaN                              NaN
# 310280         1.0                         196102.0
# 85031          5.0                              NaN
#
#         ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_YRBLD  \
# 172371                                        NaN
# 323635                                        NaN
# 291688                                        NaN
# 310280                                     1970.0
# 85031                                         NaN
#
#         ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_LOR  \
# 172371                                      NaN
# 323635                                     15.0
# 291688                                      NaN
# 310280                                      8.0
# 85031                                       NaN
#
#         ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_HHNBR  \
# 172371                                        NaN
# 323635                                        2.0
# 291688                                        NaN
# 310280                                        3.0
# 85031                                         NaN
#
#         ATTRIBUTES_SUPPLEMENTALDEMOGRAPHICS_CENS_POP_DENSITY  Alchemist  \
# 172371                                                NaN       10819.0
# 323635                                             4547.0        7552.0
# 291688                                                NaN         619.0
# 310280                                             2352.0       10702.0
# 85031                                                 NaN       18477.0
#
#         Ancient Apparition  Anti-Mage   Axe  ...  Hour_V_6  Hour_V_7  \
# 172371              7808.0       42.1  45.3  ...       102       103
# 323635              5013.0       40.9  40.8  ...       150       151
# 291688               378.0       45.9  46.6  ...       118       119
# 310280              8411.0       37.0  35.7  ...       150       151
# 85031              10865.0       37.8  36.0  ...       246       247
#
#         Hour_V_8  Hour_V_9  Hour_V_10  Hour_V_11  Hour_V_12  Hour_V_13  \
# 172371       104       105        106        107        108        109
# 323635       152       153        154        155        156        157
# 291688       120       121        122        123        124        125
# 310280       152       153        154        155        156        157
# 85031        248       249        250        251        252        253
#
#         Hour_V_14  Hour_V_15
# 172371        110        111
# 323635        158        159
# 291688        126        127
# 310280        158        159
# 85031         254        255
#
# [5 rows x 417 columns]

# %%
(X_train_embed <0).sum().sum()
# Out:
# np.int64(0)

# %%
sample = y_train.sum()

# %%
pipe = make_pipeline( simple_preprocessing
                     , StandardScaler()
                     , log_scaler 
                     , RandomForestClassifier(n_estimators=200
                                              , n_jobs=-1))

pipe.fit(X_train_embed, y_train.astype(str))
# Out:
# RuntimeWarning: invalid value encountered in log
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('simpleimputer-1',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f1f7f2907d0>),
#                                                  ('simpleimputer-2',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f1f7f280510>)])),
#                 ('standardscaler', StandardScaler()),
#                 ('functiontransformer',
#                  FunctionTransformer(func=<function log_transform at 0x7f1f7f3b19e0>)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(n_estimators=200, n_jobs=-1))])

# %%
probs = pipe.predict_proba(X_test_embeding)

result = precision_recall_curve(
                        y_true=y_test.astype(int).values
                       , probas_pred=probs[:,1])

plt.plot(result[0], result[1])
# Out:
# RuntimeWarning: invalid value encountered in log
# FutureWarning: probas_pred was deprecated in version 1.5 and will be removed in 1.7.Please use ``y_score`` instead.

# %%
y_pred = pipe.predict(X_test_embeding)
classification_result(y_true=y_test.astype(str), y_pred=y_pred)
# Out:
# RuntimeWarning: invalid value encountered in log
#               precision    recall  f1-score   support
#
#        False       0.85      1.00      0.92     82776
#         True       0.95      0.15      0.26     16731
#
#     accuracy                           0.86     99507
#    macro avg       0.90      0.57      0.59     99507
# weighted avg       0.87      0.86      0.81     99507
